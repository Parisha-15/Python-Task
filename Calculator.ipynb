# %%
a=10
b=20
# c=a+b
# print(f"value of a is {a} and value of b is {b} and value of c is {c}")
print(f"value of a is {a} and value of b is {b} and value of c is {a+b}")
# Out:
# value of a is 10 and value of b is 20 and value of c is 30
