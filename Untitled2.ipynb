# %%
max1=0
min1=100
while True:
        n=input("Enter number or press Q/q for exit")
        if n=='q' or n=='Q':
            break
        else:
            n=int(n)
            if n>max1:
                max1=n
            if n<min1:
                min1=n
                
print(f"{max1} is max")
print(f"{min1} is min")
# Out:
# Enter number or press Q/q for exit1
# Enter number or press Q/q for exit2
# Enter number or press Q/q for exit3
# Enter number or press Q/q for exit4
# Enter number or press Q/q for exitQ
# 4 is max
# 1 is min

# %%
max1=0
min1=1000000
while True:
        n=input("Enter number or press Q/q for exit")
        if n=='q' or n=='Q':
            break
        else:
            n=int(n)
            if n>max1:
                max2=max1
                max1=n
            elif n>max2 and n!=max1:
                max2=n
            if n<min1:
                min2=min1
                min1=n
            elif n<min2 and n!=min1:
                min2=n
print(f"{max1} is 1st max")
print(f"{max2} is 2nd max")
print(f"{min1} is 1st min")
print(f"{min2} is 2nd min")
# Out:
# Enter number or press Q/q for exit1
# Enter number or press Q/q for exit1
# Enter number or press Q/q for exit2
# Enter number or press Q/q for exit2
# Enter number or press Q/q for exitQ
# 2 is 1st max
# 1 is 2nd max
# 1 is 1st min
# 2 is 2nd min

# %%
emax1=0
emin1=1000000
omax1=0
omin1=1000000
while True:
        n=input("Enter number or press Q/q for exit")
        if n=='q' or n=='Q':
            break
        else:
            n=int(n)
            if n%2==0:
                if n>emax1:
                emax2=emax1
                emax1=n
            elif n>emax2 and n!=emax1:
                emax2=n
                else:
                    if n<omin1:
                    omin2=omin1
                    omin1=n
            elif n<omin2 and n!=omin1:
                omin2=n
                    
            
print(f"{emax1} is 1st max")
print(f"{emax2} is 2nd max")
print(f"{omin1} is 1st min")
print(f"{omin2} is 2nd min")
# Out:
#   File "<ipython-input-18-735417746100>", line 13
#     emax2=emax1
#     ^
# IndentationError: expected an indented block

# %%
d=int(input("Enter day: "))
m=int(input("Enter month: "))
y=int(input("Enter year: "))
if m==12 or d==31:
    d=1
    m=1
    y=y+1
elif d==31 and ((m==1) or (m==3) or (m==5) or (m==7) or (m==8) or (m==10)):
    m=m+1
    d=1
elif m==2 and (d==28 or d==29):
    if((m%400==0) or ())
