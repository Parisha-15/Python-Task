# %%
for i in range (1,11):
    if(i%2==0):
        print(i,"is even no")
    else:
        print(i,"is odd no")
# Out:
# 1 is odd no
# 2 is even no
# 3 is odd no
# 4 is even no
# 5 is odd no
# 6 is even no
# 7 is odd no
# 8 is even no
# 9 is odd no
# 10 is even no
