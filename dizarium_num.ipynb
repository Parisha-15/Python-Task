# %%
#      Disarium Number
# Eg: 89 ==> 8^1 + 9^2 ==> 89  
# Eg: 135 ==> 1^1 + 3^2 + 5^3 ==> 135 see position of 1 is : 1  , position of 3 is : 2 , position of 5 is : 3 
c=0
ans=0
n=int(input("Enter number"))
t=n
z=n
while t>0:
    t=t//10   # // gives Quotient ==> where Quotient (doesn't gives ans in decimal form) 
    c=c+1
while n>0:
    d=n%10
    ans=ans+d**c
    c=c-1
    n=n//10
if z==ans:
    print(z,"is a dizarium Number")
else:
    print(z,"is not a dizarium Number")
# Out:
# Enter number 12
# 12 is not a dizarium Number
