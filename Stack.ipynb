# %%
class SQ:
    def __init__(self,l):
        self.l=l
        print(self.l)
    def shift(self):
        try:
            if len(self.l==0):
                raise Exception("empty list")
        except Exception as e:
            print(e)
        else:
            x=self.l.pop(0)
            print(x)
            print(self.l)
    def unshift(self,u):
        self.l.insert(0,u)
        print(self.l)
    def push(self,u1):
        self.l.append(u1)
        print(self.l)
    def pop(self):
        x1=self.l.pop()
        print(x1)
        print(self.l)
    def remove(self):
        z=max(l)
        self.l.remove(z)
        print(slf.l)
        
d=SQ([1,2,3,4,5])
d.shift()
d.unshift(10)
d.push()
# Out:
# [1, 2, 3, 4, 5]
# object of type 'bool' has no len()
# [10, 1, 2, 3, 4, 5]
