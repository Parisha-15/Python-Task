# %%
n=5
for i in range(1,n+1):
    for j in range(65,i+65):
        print(chr(j),end=" ")
    print()
# Out:
# A
# A B
# A B C
# A B C D
# A B C D E

# %%
s=0
n1=int(input("Enter time in 12 hour format"))
v1=input("Enter am/pm")
n2=int(input("Enter the time you want to add on"))
if v1=="am":
    s=n1+n2
    if (s>=2 or s<=11):
        print(s,"am")
    elif (s>=12):
        s1=s%12
        print(s1,"pm")
elif v1=="pm":
    s=n1+n2
    if (s>2 or s<11):
        print(s,"pm")
    
             
else:
    print("Enter valid format")

# %%
# PROPER LOGIC CODE
for i in range(1,h+1):
    u=u+1
    if u>12:
        u=1
    if u==12:
        if day="am":
            day="pm"
        else:
            day="am"
        if day="am":
            print()

# %%
#PB 174 
n=30091998
e_num=0
m=1
while n>0:
    d=n%10
    if(d==9):
        e_d=0
    else:
        e_d=d+1
    e_num=e_num+e_d*m
    m=m*10
    n=n//10
print(e_num)
# Out:
# 41102009

# %%
# PB 144 Happy No.
n=int(input("Enter num"))
while(n!=1) and (n!=4):
    ans=0
    t=n
    while t>0:
        d=t%10
        ans=ans+d**2
        t=t//10
        n=ans
if n==1:
    print("Happy no.")
else:
    print("sad no.")
# Out:
# Enter num19
# Happy no.
