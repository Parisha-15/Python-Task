# %%
f=open("mbox-short.txt")
x=f.readlines()
c=0
for i in x:
    if "From " in i:
#         print(i)
        k=i.split(" ")

        print(k[1])
        c=c+1

#         print(k)

print("No of emails: ",c)
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# No of emails:  27

# %%
c=0
p=[]
for i in x:
    if "From " in i:
        k=i.find("From ")
        p.append(k[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e7a4fe34ea3c> in <module>
#       4     if "From " in i:
#       5         k=i.find("From ")
# ----> 6         p.append(k[1])
#
# TypeError: 'int' object is not subscriptable
