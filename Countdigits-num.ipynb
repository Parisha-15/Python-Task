# %%
# Count no of digits 
# n=123
n= int(input("Enter number"))  # input("Enter number") this is in string so we have to typecast 
                               #and make it integer to perform operations
z=n
c=0
while n>0:
    n=n//10
    c=c+1
print(z,"is a ",c," digit number")
# Out:
# Enter number 123
# 123 is a  3  digit number
