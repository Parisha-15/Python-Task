# %%
a=int(input("Enter no of hours"))
print(f"No of hours is {a} and minutes {a*60} and seconds is {a*3600}")
# Out:
# Enter no of hours1
# No of hours is 1 and minutes 60 and seconds is 3600

# %%
b=30
c=int(input("Enter no of days"))
e=c//b
print(f"No of month is e and days e//b ")
# Out:
# Enter no of days45
# No of month is e and days e//b
