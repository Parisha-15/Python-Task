# %%
f=open("9.txt")
x=f.readlines()
f.close()
print(x)
c=0
for i in x:
    c=c+1
    if "dhruv" in i:
        k=i.find("dhruv")
        print(f"line no {i} and index {k}")
# Out:
# ['dhruv\n', 'hello bye how\n', 'are you\n', 'cricket\n', 'dhoni captain cool\n', 'hello dhruv\n', 'indian Cricket world cup 2026\n', 'ahd is clean city\n', 'python(ai\\ml) is future of tech']
# line no dhruv
#  and index 0
# line no hello dhruv
#  and index 6
