# %%
# %%writefile ae.py
a=0
def l():
    z=input("Enter str u want to fine length")
    a=len(z)
    print(f"length of str is: {z} is: {a}")
# Out:
# Writing ae.py

# %%
import ae
ae.l()
# Out:
# Enter str u want to fine lengthParisha
# length of str is: Parisha is: 7

# %%
import ae as p
p.l()
ae.l()
# Out:
# Enter str u want to fine lengthe3f
# length of str is: e3f is: 3

# %%
from ae import l()

# %%
# %%writefile aap.py
def w():
    c="this is python programming"
    x=c.split()
    k=x[0]
    print(k)

# %%
import aa
aap.w()
