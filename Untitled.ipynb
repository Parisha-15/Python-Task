# %%
# n=int(input("Enter number"))
# ans=0
# sum=0
# while n>0:
#     digit=n%10
# #      ans=(ans*10)+digit
# ans=ans+digit
# n=n//10
# print(sum)

# %%
z=int(input("Enter number"))
ans=0
n=z
while n>0:
    digit=n%10
    ans=ans+(digit**3)
    n=n//10
if n==z:
    print("armstong")
else:
    print("not armstorng")
