# %%
# Particular power to the number  eg: 1293 ==> 1^2 +2^2 + 9^2 + 3^2
c=0
ans=0
n=int(input("Enter your number"))
z=n   # to print the input number
while n>0:
    d=n%10
    ans=ans+d**2  # ** ==> used for power
    n=n//10
print(ans)
# Out:
# Enter your number 123
# 4.146264369941973
