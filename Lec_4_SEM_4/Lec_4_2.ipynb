# %%
import pandas as pd
df=pd.read_csv("social_media_engagement.csv")

# %%
df
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
df.head()
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 1        2   Facebook  carousel   5/14/2023 0:45   3660       432     694
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
# 4        5    Twitter     video   5/23/2023 0:30   3499       247     286
#
#    post_day sentiment_score
# 0  Thursday        positive
# 1    Sunday         neutral
# 2   Tuesday        negative
# 3  Thursday        negative
# 4   Tuesday        positive

# %%
df.tail()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# 95  Wednesday        positive
# 96     Friday         neutral
# 97   Saturday        positive
# 98     Friday        positive
# 99    Tuesday         neutral

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   post_id          100 non-null    int64
#  1   platform         100 non-null    object
#  2   post_type        100 non-null    object
#  3   post_time        100 non-null    object
#  4   likes            100 non-null    int64
#  5   comments         100 non-null    int64
#  6   shares           100 non-null    int64
#  7   post_day         100 non-null    object
#  8   sentiment_score  100 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
df.isna().sum()
# Out:
# post_id            0
# platform           0
# post_type          0
# post_time          0
# likes              0
# comments           0
# shares             0
# post_day           0
# sentiment_score    0
# dtype: int64

# %%
df.dtypes
# Out:
# post_id             int64
# platform           object
# post_type          object
# post_time          object
# likes               int64
# comments            int64
# shares              int64
# post_day           object
# sentiment_score    object
# dtype: object

# %%
df.nunique()
# Out:
# post_id            100
# platform             3
# post_type            5
# post_time           99
# likes               93
# comments            85
# shares              96
# post_day             7
# sentiment_score      3
# dtype: int64

# %%
df.columns
# Out:
# Index(['post_id', 'platform', 'post_type', 'post_time', 'likes', 'comments',
#        'shares', 'post_day', 'sentiment_score'],
#       dtype='object')

# %%
df.platform.unique()
# Out:
# array(['Facebook', 'Instagram', 'Twitter'], dtype=object)

# %%
df.post_type.unique()
# Out:
# array(['image', 'carousel', 'poll', 'video', 'text'], dtype=object)

# %%
df.sentiment_score.unique()
# Out:
# array(['positive', 'neutral', 'negative'], dtype=object)

# %%
df.platform
# Out:
# 0      Facebook
# 1      Facebook
# 2     Instagram
# 3       Twitter
# 4       Twitter
#         ...
# 95    Instagram
# 96      Twitter
# 97      Twitter
# 98    Instagram
# 99    Instagram
# Name: platform, Length: 100, dtype: object

# %%
df.groupby("platform")["likes"].sum()
# Out:
# platform
# Facebook      86392
# Instagram    107994
# Twitter       43795
# Name: likes, dtype: int64

# %%
df.groupby("platform")["likes"].sum()

# %%
df.groupby("platform")[["likes","comments","shares"]].sum()
# Out:
#             likes  comments  shares
# platform
# Facebook    86392      7965   15180
# Instagram  107994      8368   18906
# Twitter     43795      3933    7479

# %%
# (lambda x: y= df.groupby("platform")["likes"].sum() if y<50000 x="v.good" else x="good")
# Out:
#   File "<ipython-input-43-cf01a9fd116b>", line 1
#     df.apply(lambda x: y= df.groupby("platform")["likes"].sum() if y<50000 x="v.good" else x="good")
#                                                                            ^
# SyntaxError: invalid syntax

# %%
x=df.groupby("platform")["likes"].sum().apply(lambda x: "good" if x>50000 else "v.good")

# %%
x
# Out:
# platform
# Facebook       good
# Instagram      good
# Twitter      v.good
# Name: likes, dtype: object

# %%
df.groupby("platform").head()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# 5         6  Instagram  carousel    5/5/2023 20:00    256       186     211
# 6         7  Instagram     image   2/26/2023 11:45   1982        30     906
# 7         8  Instagram      text  10/28/2023 19:30   1274        45     216
# 8         9   Facebook     video     5/2/2023 6:15    317       249     221
# 9        10    Twitter  carousel   5/11/2023 11:00   1878       225     438
# 10       11    Twitter      text    12/8/2023 2:15   1446        44      52
# ...

# %%
df.groupby("platform").tail()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 76       77    Twitter  carousel    7/5/2023 18:15   3571       102      96
# 84       85   Facebook      text     7/6/2023 7:00   2566       368     304
# 85       86    Twitter      text   11/25/2023 7:30   2416        50      62
# 87       88   Facebook      text    5/3/2023 12:30   3404       244      67
# 88       89    Twitter  carousel     5/3/2023 8:00   2884       197     339
# 90       91   Facebook  carousel    9/15/2023 0:45   3956       402     462
# 91       92   Facebook     video   2/23/2023 17:15   1857       216     344
# 92       93  Instagram  carousel     5/7/2023 0:30    951       432     734
# 93       94   Facebook     image   11/27/2023 4:30   1694       207     290
# 94       95  Instagram      poll    3/7/2023 19:15   3005       124     517
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# ...

# %%
df.groupby("platform").sample()
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 12       13   Facebook  carousel  11/11/2023 15:45     45        78     375
# 23       24  Instagram  carousel    1/1/2023 20:00   5000        80     399
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
#
#     post_day sentiment_score
# 12  Saturday        negative
# 23    Sunday        positive
# 96    Friday         neutral

# %%
df.groupby("platform").describe()
# Out:
#           post_id                                                       likes  \
#             count       mean        std  min    25%   50%    75%    max count
# platform
# Facebook     32.0  51.531250  29.195652  1.0  28.75  53.0  76.25   94.0  32.0
# Instagram    36.0  57.472222  28.866675  3.0  38.75  60.5  79.75  100.0  36.0
# Twitter      32.0  41.625000  27.492814  4.0  18.75  39.5  56.00   98.0  32.0
#
#                         ... comments        shares                          \
#                   mean  ...      75%    max  count        mean         std
# platform                ...
# Facebook   2699.750000  ...   393.00  500.0   32.0  474.375000  299.739430
# Instagram  2999.833333  ...   339.00  500.0   36.0  525.166667  284.467472
# Twitter    1368.593750  ...   162.25  247.0   32.0  233.718750  156.508525
#
#
#             min     25%    50%     75%    max
# platform
# Facebook   16.0  283.00  408.5  728.75  993.0
# Instagram  25.0  226.50  573.5  758.00  956.0
# ...

# %%
df.groupby("platform").describe().sum()
# Out:
# post_id   count      100.000000
#           mean       150.628472
#           std         85.555141
#           min          8.000000
#           25%         86.250000
#           50%        153.000000
#           75%        212.000000
#           max        292.000000
# likes     count      100.000000
#           mean      7068.177083
#           std       4327.125298
#           min        179.000000
#           25%       3653.500000
#           50%       6868.000000
#           75%      10936.750000
#           max      13571.000000
# comments  count      100.000000
#           mean       604.256944
#           std        358.166283
#           min         55.000000
#           25%        296.000000
#           50%        562.000000
#           75%        894.250000
#           max       1247.000000
# shares    count      100.000000
#           mean      1233.260417
#           std        740.715427
#           min         59.000000
#           25%        603.750000
# ...

# %%
df.groupby("platform").describe().mean()
# Out:
# post_id   count      33.333333
#           mean       50.209491
#           std        28.518380
#           min         2.666667
#           25%        28.750000
#           50%        51.000000
#           75%        70.666667
#           max        97.333333
# likes     count      33.333333
#           mean     2356.059028
#           std      1442.375099
#           min        59.666667
#           25%      1217.833333
#           50%      2289.333333
#           75%      3645.583333
#           max      4523.666667
# comments  count      33.333333
#           mean      201.418981
#           std       119.388761
#           min        18.333333
#           25%        98.666667
#           50%       187.333333
#           75%       298.083333
#           max       415.666667
# shares    count      33.333333
#           mean      411.086806
#           std       246.905142
#           min        19.666667
#           25%       201.250000
#           50%       399.666667
# ...

# %%
df.groupby("platform").describe().value_counts()
# Out:
# (post_id, count)  (post_id, mean)  (post_id, std)  (post_id, min)  (post_id, 25%)  (post_id, 50%)  (post_id, 75%)  (post_id, max)  (likes, count)  (likes, mean)  (likes, std)  (likes, min)  (likes, 25%)  (likes, 50%)  (likes, 75%)  (likes, max)  (comments, count)  (comments, mean)  (comments, std)  (comments, min)  (comments, 25%)  (comments, 50%)  (comments, 75%)  (comments, max)  (shares, count)  (shares, mean)  (shares, std)  (shares, min)  (shares, 25%)  (shares, 50%)  (shares, 75%)  (shares, max)
# ...

# %%
df.groupby("platform").size()
# Out:
# platform
# Facebook     32
# Instagram    36
# Twitter      32
# dtype: int64

# %%
df.shape
# Out:
# (100, 9)

# %%
df
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 0         1   Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2   Facebook  carousel    5/14/2023 0:45   3660       432     694
# 2         3  Instagram      poll   2/21/2023 16:15   4955       408     688
# 3         4    Twitter     image   11/16/2023 0:45   1183        90     187
# 4         5    Twitter     video    5/23/2023 0:30   3499       247     286
# ..      ...        ...       ...               ...    ...       ...     ...
# 95       96  Instagram  carousel   7/12/2023 17:45     36       294     911
# 96       97    Twitter     video  10/27/2023 23:45    314       108     458
# 97       98    Twitter      text     8/5/2023 8:45    229       179      38
# 98       99  Instagram      poll  12/29/2023 12:15   5000       500     204
# 99      100  Instagram     image    6/6/2023 21:00   4483       357      25
#
#      post_day sentiment_score
# ...

# %%
df.groupby("platform").groups
# Out:
# {'Facebook': [0, 1, 8, 12, 14, 19, 25, 27, 28, 29, 30, 35, 36, 38, 46, 47, 57, 61, 65, 66, 69, 71, 72, 74, 79, 80, 83, 84, 87, 90, 91, 93], 'Instagram': [2, 5, 6, 7, 16, 23, 26, 31, 34, 39, 41, 43, 45, 49, 53, 55, 56, 59, 60, 63, 64, 67, 70, 73, 75, 77, 78, 81, 82, 86, 89, 92, 94, 95, 98, 99], 'Twitter': [3, 4, 9, 10, 11, 13, 15, 17, 18, 20, 21, 22, 24, 32, 33, 37, 40, 42, 44, 48, 50, 51, 52, 54, 58, 62, 68, 76, 85, 88, 96, 97]}

# %%
for i,j in df.groupby("platform"):
    print(i,"name")
    print(j,"data")
# Out:
# Facebook name
#     post_id  platform post_type         post_time  likes  comments  shares  \
# 0         1  Facebook     image   8/17/2023 14:45   2121       474     628
# 1         2  Facebook  carousel    5/14/2023 0:45   3660       432     694
# 8         9  Facebook     video     5/2/2023 6:15    317       249     221
# 12       13  Facebook  carousel  11/11/2023 15:45     45        78     375
# 14       15  Facebook  carousel    1/9/2023 20:00    889       314     262
# 19       20  Facebook     image    2/2/2023 16:00    455        86      79
# 25       26  Facebook  carousel    10/5/2023 6:30   1992        70     515
# 27       28  Facebook      poll     3/1/2023 8:00   2083       500     388
# 28       29  Facebook     image    1/7/2023 10:30    548       153     731
# 29       30  Facebook  carousel     2/3/2023 0:30   4594       216     739
# 30       31  Facebook      poll   9/10/2023 13:45   4795       449     978
# ...

# %%
df.groupby("platform").nth(0)
# Out:
#    post_id   platform post_type        post_time  likes  comments  shares  \
# 0        1   Facebook     image  8/17/2023 14:45   2121       474     628
# 2        3  Instagram      poll  2/21/2023 16:15   4955       408     688
# 3        4    Twitter     image  11/16/2023 0:45   1183        90     187
#
#    post_day sentiment_score
# 0  Thursday        positive
# 2   Tuesday        negative
# 3  Thursday        negative

# %%
df.groupby("platform").nth(3)
# Out:
#     post_id   platform post_type         post_time  likes  comments  shares  \
# 7         8  Instagram      text  10/28/2023 19:30   1274        45     216
# 10       11    Twitter      text    12/8/2023 2:15   1446        44      52
# 12       13   Facebook  carousel  11/11/2023 15:45     45        78     375
#
#     post_day sentiment_score
# 7   Saturday         neutral
# 10    Friday        negative
# 12  Saturday        negative

# %%
df.groupby("platform").nunique()
# Out:
#            post_id  post_type  post_time  likes  comments  shares  post_day  \
# platform
# Facebook        32          5         32     29        28      32         7
# Instagram       36          5         36     33        34      36         7
# Twitter         32          5         32     32        31      31         7
#
#            sentiment_score
# platform
# Facebook                 3
# Instagram                3
# Twitter                  3

# %%
df.groupby("platform").agg({"likes":sum,"comments":max})
# Out:
#             likes  comments
# platform
# Facebook    86392       500
# Instagram  107994       500
# Twitter     43795       247
