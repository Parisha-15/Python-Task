# %%
s=0
c=0
while True:
        n=input("Enter number or press Q/q for exit")
        if n=='q' or n=='Q':
            break
        else:
            n=int(n)
            s=s+n
            c=c+1
       
       
print(f"sum {s} and count {c} and avg {s/c}")
# Out:
# Enter number or press Q/q for exit123
# Enter number or press Q/q for exit12
# Enter number or press Q/q for exitQ
# sum 135 and count 2 and avg 67.5
