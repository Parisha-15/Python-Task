# %%
# u have to use below statement for abstraction
from abc import ABC,abstractmethod
class Defense(ABC):
    @abstractmethod 
    def Gun(self):
        Pass
    def show (self):
        print("hELLO")
class Army(Defense):
    def Gun(self):
        print("AK-47")
class navy(Army):
    def Gun(self):
        print("AUG")
a=Army()
a.Gun()
n=navy()
n.Gun()
# d=Defense()  TypeError: Can't instantiate abstract class Defense with abstract methods Gun
# Out:
# AK-47
# AUG
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-fa1c73608751> in <module>
#      17 n=navy()
#      18 n.Gun()
# ---> 19 d=Defense()
#
# TypeError: Can't instantiate abstract class Defense with abstract methods Gun
